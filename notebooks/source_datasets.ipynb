# %%
import pandas as pd

# %% [markdown]
# # Dataset overview from public domain

# %% [markdown]
# ## Discogs Datasets (January 2025)
#
# Source: https://www.kaggle.com/datasets/ofurkancoban/discogs-datasets-january-2025
#
# This file contains detailed information about artists from the Discogs Data Dump as of January 1, 2025. It provides structured data about individual artists, including their names, unique IDs, profiles, and related information, all in CSV format.
#
# Columns:
# • Artist ID: Unique identifier for each artist.
# • Artist Name: The name of the artist.
# • Profile: A short description or biography of the artist.
# • Real Name: The real name of the artist (if available).
# • Aliases: Alternative names or pseudonyms used by the artist.
# • Groups: Bands or groups the artist is associated with.
# • URLs: Links to external websites or profiles related to the artist.
# • Data Quality: Indicates the quality or completeness of the data entry.
#
# Use Case:
# This file is ideal for applications like music cataloging, trend analysis, artist mapping, or building recommendation systems based on artist relationships and metadata.

# %%
# this path is ignored by git
path1="../datasets/discogs_20250101_artists.csv"

# to load from a backup
data_1 = pd.read_csv(path1)
df1 = data_1.copy()
df1.sample(10)
# Out:
#          Unnamed: 0 aliases_name  aliases_name_id  artist_data_quality  \
# 7902522     7902522          NaN              NaN           Needs Vote
# 8391085     8391085          NaN              NaN  Needs Major Changes
# 4303827     4303827          NaN              NaN  Needs Major Changes
# 4088982     4088982          NaN              NaN  Needs Major Changes
# 1557361     1557361          NaN              NaN  Needs Major Changes
# 5391577     5391577          NaN              NaN  Needs Major Changes
# 4303540     4303540          NaN              NaN  Needs Major Changes
# 3040798     3040798          NaN              NaN  Needs Major Changes
# 2918764     2918764          NaN              NaN  Needs Major Changes
# 9038380     9038380          NaN              NaN  Needs Major Changes
#
#          artist_id                          artist_name  \
# 7902522    1045631                         Fred Robbins
# 8391085   12844265  The Millennium Promise Jazz Project
# 4303827    5795050                            The Fuse!
# 4088982    5551723                            Ena Beats
# 1557361    2921278               Keijo Kaivo-ojan Yhtye
# 5391577    6905196       The Kathleen Stobart Orchestra
# 4303540    5794732                               Ya Nur
# 3040798    4464573                 Gabriella Chiavarini
# 2918764    4338251                                Candé
# 9038380   14657028                       Torture Hammer
#
#                       artist_profile artist_realname groups_name  \
# 7902522  Radio disc jockey/producer.             NaN         NaN
# 8391085                          NaN             NaN         NaN
# 4303827                          NaN             NaN         NaN
# 4088982                          NaN             NaN         NaN
# 1557361                          NaN             NaN         NaN
# 5391577                          NaN             NaN         NaN
# 4303540                          NaN             NaN         NaN
# 3040798                          NaN             NaN         NaN
# 2918764                          NaN             NaN         NaN
# 9038380                          NaN             NaN         NaN
#
#          groups_name_id   members_name  members_name_id namevariations_name  \
# 7902522             NaN            NaN              NaN             Robbins
# 8391085             NaN            NaN              NaN                 NaN
# 4303827             NaN            NaN              NaN            The Fuse
# 4088982             NaN            NaN              NaN                 NaN
# 1557361             NaN   Paavo Kauppi        2921245.0                 NaN
# 5391577             NaN  Kathy Stobart        1744473.0                 NaN
# 4303540             NaN       Bira (3)         751467.0                 NaN
# 3040798             NaN            NaN              NaN                 NaN
# 2918764             NaN            NaN              NaN                 NaN
# 9038380             NaN            NaN              NaN                 NaN
#
#         urls_url
# 7902522      NaN
# 8391085      NaN
# 4303827      NaN
# 4088982      NaN
# 1557361      NaN
# 5391577      NaN
# 4303540      NaN
# 3040798      NaN
# 2918764      NaN
# 9038380      NaN

# %%
df1.shape
# Out:
# (9194907, 14)

# %% [markdown]
# ## Discogs Database All Release Data
# This dataset encompasses over 13 million recordings, providing a broad view of music distribution and physical sales, particularly vinyl records.
#
# https://www.kaggle.com/datasets/sohrabdaemi/discogs-database-all-release-data

# %%
# this path is ignored by git
path2="../datasets/release_data.csv"

data_2 = pd.read_csv(path2)
df2 = data_2.copy()
df2.sample(10)
# Out:
#           release_id    country    year                   genre format
# 14203964    12881539    Germany  2018.0              Electronic   File
# 14935498    13541183  Australia     NaN          Stage & Screen  Vinyl
# 5560994      4875823      Japan  1987.0                    Rock  Vinyl
# 3782345      3349169         US  2011.0              Electronic   File
# 10161797     9088099     Europe  2014.0                     Pop  Vinyl
# 3158778      2845130     France  2010.0              Electronic   File
# 4960018      4346109      Spain  1966.0                   Latin  Vinyl
# 15455520    14004841     France  2007.0                    Rock     CD
# 6401333      5638779  Australia  2010.0                    Rock     CD
# 2101145      1985537         US  1989.0  Folk, World, & Country  Vinyl

# %%
df2.shape
# Out:
# (17372035, 5)

# %% [markdown]
# ## Bandcamp

# %% [markdown]
# Source: https://www.kaggle.com/datasets/mathurinache/1000000-bandcamp-sales
#
# This dataset contains 1,000,000 items from Bandcamp's sales feed between 9/9/2020 and 10/2/2020, and is a slice of the whole dataset used in The Chaos Bazaar. It contains the following columns:
#
# - _id: unique identifier combining the sale's URL and UTC timestamp.
# - url: the path to the item on Bandcamp. Use this column to join this dataset to the dataset of Bandcamp items.
# - artist_name: Name of the artist.
# - album_title: Title of the album, if applicable.
# - art_url: path to the item's art image.
# - item_type: denotes the type of object. a for digital albums, p for physical items, and t for digital tracks.
# - slug_type: also denotes the type of object. a for all albums, p for merch, and t for tracks.
# - utc_date: the UTC timestamp of the sale datetime.
# - country_code: country code of the buyer.
# - country: full country code name of the buyer.
# - item_price: price of the item in the seller's currency.
# - currency: the seller's currency.
# - amount_paid: amount paid in the seller's currency.
# - amount_paid_fmt: amount paid in the seller's currency, with the currency symbol.
# - amount_paid_usd: amount paid converted to US Dollars.
# - amount_over_fmt: amount voluntarily paid over the item price in the seller's currency.
#
# Sample code, charts and reports:
# https://www.kaggle.com/code/mathurinache/bandcamp-dataset-starter

# %%
# this path is ignored by git
path3="../datasets/1000000-bandcamp-sales.csv"

data_3 = pd.read_csv(path3)
df3 = data_3.copy()
df3.sample(10)
# Out:
#                                                       _id  \
# 52057   1599804596.68458&//amphiarecords.bandcamp.com/...
# 367661  1600461044.51009&//diamondortiz.bandcamp.com/a...
# 733003  1601234408.80457&//sundaybest.bandcamp.com/alb...
# 58964   1599819547.21387&//catherinemajor.bandcamp.com...
# 538282  1600864533.98496&//agvarcrds.bandcamp.com/trac...
# 943465  1601633004.99411&//deathkvltproductions.bandca...
# 725414  1601220007.31343&//iamtheos.bandcamp.com/track...
# 951591  1601635557.96612&//glossymistakes.bandcamp.com...
# 724779  1601218902.48877&//twrp.bandcamp.com/album/gua...
# 406702  1600538676.38562&//boldconnectionsunlimited.ba...
#
#                                             art_url item_type      utc_date  \
# 52057   https://f4.bcbits.com/img/a0826275630_7.jpg         t  1.599805e+09
# 367661  https://f4.bcbits.com/img/0021672698_37.jpg         p  1.600461e+09
# 733003  https://f4.bcbits.com/img/a1130873696_7.jpg         a  1.601234e+09
# 58964   https://f4.bcbits.com/img/a0280256802_7.jpg         t  1.599820e+09
# 538282  https://f4.bcbits.com/img/a0664932743_7.jpg         t  1.600865e+09
# 943465  https://f4.bcbits.com/img/0021653633_37.jpg         p  1.601633e+09
# 725414  https://f4.bcbits.com/img/a0668718392_7.jpg         t  1.601220e+09
# 951591  https://f4.bcbits.com/img/0021814716_37.jpg         p  1.601636e+09
# 724779  https://f4.bcbits.com/img/a4126128372_7.jpg         a  1.601219e+09
# 406702  https://f4.bcbits.com/img/a2614982620_7.jpg         t  1.600539e+09
#
#        country_code track_album_slug_text         country slug_type  \
# 52057            au                   NaN       Australia         t
# 367661           nl                   NaN     Netherlands         a
# 733003           us                   NaN   United States         a
# 58964            fr                   NaN          France         t
# 538282           id                   NaN       Indonesia         t
# 943465           us                   NaN   United States         a
# 725414           gb                   NaN  United Kingdom         t
# 951591           gb                   NaN  United Kingdom         a
# 724779           jp                   NaN           Japan         a
# 406702           be                   NaN         Belgium         t
#
#        amount_paid_fmt  item_price  ... amount_paid  releases  \
# 52057               €2        2.00  ...        2.00       NaN
# 367661             $25       25.00  ...       25.00       NaN
# 733003              £7        7.00  ...        7.00       NaN
# 58964           $2 CAD        1.00  ...        2.00       NaN
# 538282              $2        2.00  ...        2.00       NaN
# 943465              £7        7.00  ...        7.00       NaN
# 725414           €1.29        1.29  ...        1.29       NaN
# 951591             €22       22.00  ...       22.00       NaN
# 724779              $6        6.00  ...        6.00       NaN
# 406702              $5        5.00  ...        5.00       NaN
#
#                artist_name  currency                     album_title  \
# 52057                Amorf       EUR                   Dimensions EP
# 367661       Diamond Ortiz       USD                  Classy Chassis
# 733003         Wild Smiles       GBP                             NaN
# 58964      Catherine Major       CAD                      Carte mère
# 538282  O.L.I.V.I.A x MAJA       USD                             NaN
# 943465     Lamp of Murmuur       GBP  Heir of Ecliptical Romanticism
# 725414               THEOS       EUR                             NaN
# 951591             Yas-Kaz       EUR       Yas-Kaz - Jomon-sho (縄文頌)
# 724779                TWRP       USD                             NaN
# 406702   Barbara Marciniak       USD                             NaN
#
#        amount_paid_usd package_image_id amount_over_fmt  item_slug  addl_count
# 52057             2.36              NaN             NaN        NaN         NaN
# 367661           25.00       21672698.0             NaN        NaN         NaN
# 733003            8.92              NaN             NaN        NaN         NaN
# 58964             1.52              NaN             NaN        NaN         NaN
# 538282            2.00              NaN             NaN        NaN         NaN
# 943465            9.00       21653633.0             NaN        NaN         NaN
# 725414            1.50              NaN             NaN        NaN         NaN
# 951591           25.78       21814716.0             NaN        NaN         NaN
# 724779            6.00              NaN             NaN        NaN         NaN
# 406702            5.00              NaN             NaN        NaN         NaN
#
# [10 rows x 23 columns]

# %%
df3.shape
# Out:
# (1000000, 23)
