# %%
import pandas as pd
from src import datasets

# %%
# Setup: create dataframes from perdownloaded csv files, excluded from git repo
# all these files can be downloaded from the web pages linked below

datasets_files = [
'1000000-bandcamp-sales.csv', 
'discogs_20250101_artists.csv', 
'release_data.csv']

project_pack = datasets.DatasetPack()

ds_bandcamp_sales = datasets.Dataset('df_bandcamp_sales', datasets_files[0])
project_pack.add_dataset(ds_bandcamp_sales)
df_bandcamp_sales = ds_bandcamp_sales.dataframe

ds_discogs_artists = datasets.Dataset('df_discogs_artists', datasets_files[1])
project_pack.add_dataset(ds_discogs_artists)
df_discogs_artists = ds_discogs_artists.dataframe

ds_discogs_releases = datasets.Dataset('df_discogs_releases', datasets_files[2])
project_pack.add_dataset(ds_discogs_releases)
df_discogs_releases = ds_discogs_releases.dataframe

print(f"The following data frames are created with corresponding labels in data set pack:\n {project_pack.get_labels()}")
# Out:
# The following data frames are created with corresponding labels in data set pack:
#  ['df_bandcamp_sales', 'df_discogs_artists', 'df_discogs_releases']

# %% [markdown]
# # Datasets raw source overview

# %% [markdown]
# ## Discogs Datasets (January 2025)
#
# Source: https://www.kaggle.com/datasets/ofurkancoban/discogs-datasets-january-2025
#
# This file contains detailed information about artists from the Discogs Data Dump as of January 1, 2025.
#
# It provides structured data about individual artists, including their names, unique IDs, profiles, and related information, all in CSV format.
#
# Columns:
# - Artist ID: Unique identifier for each artist.
# - Artist Name: The name of the artist.
# - Profile: A short description or biography of the artist.
# - Real Name: The real name of the artist (if available).
# - Aliases: Alternative names or pseudonyms used by the artist.
# - Groups: Bands or groups the artist is associated with.
# - URLs: Links to external websites or profiles related to the artist.
# - Data Quality: Indicates the quality or completeness of the data entry.
#
# Use Case:
# This file is ideal for applications like music cataloging, trend analysis, artist mapping, or building recommendation systems based on artist relationships and metadata.

# %%
df_discogs_artists.sample(30)
# Out:
#          Unnamed: 0   aliases_name  aliases_name_id  artist_data_quality  \
# 4753567     4753567            NaN              NaN           Needs Vote
# 8659321     8659321            NaN              NaN  Needs Major Changes
# 5771649     5771649            NaN              NaN           Needs Vote
# 110709       110709            NaN              NaN           Needs Vote
# 4992934     4992934            NaN              NaN  Needs Major Changes
# 5533633     5533633            NaN              NaN  Needs Major Changes
# 621312       621312            NaN              NaN  Needs Major Changes
# 3725672     3725672            NaN              NaN           Needs Vote
# 6500530     6500530            NaN              NaN  Needs Major Changes
# 4675356     4675356            NaN              NaN           Needs Vote
# 7125051     7125051            NaN              NaN              Correct
# 2028709     2028709            NaN              NaN  Needs Major Changes
# 1075755     1075755            NaN              NaN  Needs Major Changes
# 3939121     3939121            NaN              NaN  Needs Major Changes
# 7283511     7283511            NaN              NaN           Needs Vote
# 2630333     2630333            NaN              NaN  Needs Major Changes
# 898212       898212            NaN              NaN  Needs Major Changes
# 1007241     1007241            NaN              NaN  Needs Major Changes
# 5142877     5142877            NaN              NaN  Needs Major Changes
# 8965175     8965175            NaN              NaN  Needs Major Changes
# 6756850     6756850            NaN              NaN           Needs Vote
# 5289050     5289050            NaN              NaN  Needs Major Changes
# 828147       828147            NaN              NaN  Needs Major Changes
# 905930       905930  The Wolf Pack        1307365.0           Needs Vote
# 2743075     2743075          Ranxx        2017194.0  Needs Major Changes
# 3534845     3534845            NaN              NaN  Needs Major Changes
# 799395       799395     Figo Sound        8153162.0           Needs Vote
# 5485682     5485682            NaN              NaN  Needs Major Changes
# 5328388     5328388            NaN              NaN  Needs Major Changes
# 3503869     3503869            NaN              NaN  Needs Major Changes
#
#          artist_id            artist_name  artist_realname  \
# 4753567    6264626        Gérald Daragnes              NaN
# 8659321   13626688           Die Watussis              NaN
# 5771649    7279387             Buku Broux              NaN
# 110709     1373711          Dorota Ślęzak              NaN
# 4992934    6509048       Henry Posada (2)              NaN
# 5533633    7051041             D.D.B. (3)              NaN
# 621312     1924144  Cassie Brzoza Designs              NaN
# 3725672    5156574      M. Willingham (2)              NaN
# 6500530    7999375                 T.NAVA              NaN
# 4675356    6188703            Bryan Brady              NaN
# 7125051     963000       R. Meir-Oliviera              NaN
# 2028709    3420054             К. Смирнов              NaN
# 1075755    2412608         Ariel Alvarado              NaN
# 3939121    5377988            Jurie Nanbu              NaN
# 7283511    9667147     Alessandro Cazzato              NaN
# 2630333    4045458         Rüdiger Hamann              NaN
# 898212     2229094   Tout Sullivan Thomas              NaN
# 1007241    2344253     Franco Disque Inc.              NaN
# 5142877    6652689                  JLoki              NaN
# 8965175   14459957              Dame (26)              NaN
# 6756850    8245464          Jamie Gosling              NaN
# 5289050    6803168    Johannes Jensen (2)              NaN
# 828147     2146343          Jack Bosswell              NaN
# 905930      269090            The Animals              NaN
# 2743075    4162439         Quentin Dubois              NaN
# 3534845    4964477             Max Quatro              NaN
# 799395      261080        Stefano Colombo  Stefano Colombo
# 5485682    6998105             Abra Sempe              NaN
# 5328388    6846557   Cosmörs Trommler Bär              NaN
# 3503869    4929463     Frank F. Pettirsch              NaN
#
#                            groups_name  groups_name_id   members_name  \
# 4753567                         Tample       4587682.0            NaN
# 8659321                            NaN             NaN            NaN
# 5771649                            NaN             NaN            NaN
# 110709            Piwnica Pod Baranami       3127081.0            NaN
# 4992934                            NaN             NaN            NaN
# 5533633                            NaN             NaN            NaN
# 621312                             NaN             NaN            NaN
# 3725672                      Phaze (4)       1198096.0            NaN
# 6500530                            NaN             NaN            NaN
# 4675356                  Locked Up (2)       8167408.0            NaN
# 7125051                            NaN             NaN            NaN
# 2028709                            NaN             NaN            NaN
# 1075755                            NaN             NaN            NaN
# 3939121                            NaN             NaN            NaN
# 7283511                   Archimie Duo       9667141.0            NaN
# 2630333                            NaN             NaN            NaN
# 898212                             NaN             NaN            NaN
# 1007241                            NaN             NaN            NaN
# 5142877                            NaN             NaN            NaN
# 8965175                            NaN             NaN            NaN
# 6756850             Moving Targets (9)       8245463.0            NaN
# 5289050                            NaN             NaN            NaN
# 828147                             NaN             NaN            NaN
# 905930                             NaN             NaN  Dave Rowberry
# 2743075                            NaN             NaN            NaN
# 3534845                            NaN             NaN            NaN
# 799395   Brazilian Love Affair Project       4188300.0            NaN
# 5485682                            NaN             NaN            NaN
# 5328388                            NaN             NaN            NaN
# 3503869                            NaN             NaN            NaN
#
#          members_name_id      namevariations_name
# 4753567              NaN          Gérald Daragnès
# 8659321              NaN                      NaN
# 5771649              NaN                      NaN
# 110709               NaN                      NaN
# 4992934              NaN                      NaN
# 5533633              NaN                      NaN
# 621312               NaN                      NaN
# 3725672              NaN                      NaN
# 6500530              NaN                      NaN
# 4675356              NaN                    Bryan
# 7125051              NaN                      NaN
# 2028709              NaN                      NaN
# 1075755              NaN                      NaN
# 3939121              NaN                      NaN
# 7283511              NaN                      NaN
# 2630333              NaN                      NaN
# 898212               NaN                      NaN
# 1007241              NaN                      NaN
# 5142877              NaN                      NaN
# 8965175              NaN                      NaN
# 6756850              NaN                      NaN
# 5289050              NaN                      NaN
# 828147               NaN                      NaN
# 905930          902686.0                  ジ・アニマルズ
# 2743075              NaN                      NaN
# 3534845              NaN                      NaN
# 799395               NaN  Stefano Colombo's Touch
# 5485682              NaN                      NaN
# 5328388              NaN                      NaN
# 3503869              NaN                      NaN

# %%
df_discogs_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9194907 entries, 0 to 9194906
# Data columns (total 14 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Unnamed: 0           int64
#  1   aliases_name         object
#  2   aliases_name_id      float64
#  3   artist_data_quality  object
#  4   artist_id            int64
#  5   artist_name          object
#  6   artist_profile       object
#  7   artist_realname      object
#  8   groups_name          object
#  9   groups_name_id       float64
#  10  members_name         object
#  11  members_name_id      float64
#  12  namevariations_name  object
#  13  urls_url             object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 982.1+ MB

# %% [markdown]
# #### Dropping columns that are not important for sure in the context of this project

# %%
columns_to_drop = ['artist_profile', 'urls_url']
df_discogs_artists.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# #### Backing up the dataframe for further use

# %%
project_pack.dictionary['df_discogs_artists'].backup()

# %% [markdown]
# ## Discogs Database All Release Data
# This dataset encompasses over 13 million recordings, providing a broad view of music distribution and physical sales, particularly vinyl records.
#
# https://www.kaggle.com/datasets/sohrabdaemi/discogs-database-all-release-data

# %%
df_discogs_releases.sample(20)
# Out:
#           release_id    country    year                   genre   format
# 16893939    15298365      Spain  2020.0          Stage & Screen       CD
# 16621910    15050527      Spain  2014.0                    Rock  Blu-ray
# 14043833    12738261    Germany     NaN                     Pop       CD
# 16563617    14997486         UK  2019.0              Electronic     File
# 8985756      8002855    Germany  2014.0                    Rock  Box Set
# 15731071    14250460      Italy  2009.0              Electronic     File
# 4301111      3772374         UK  2009.0              Electronic     File
# 3393673      3035502      Japan  2001.0              Electronic       CD
# 3589073      3193827     Europe  2007.0                    Rock       CD
# 728079        758962         UK     NaN              Electronic    Vinyl
# 6946347      6129100     France  1981.0              Electronic    Vinyl
# 8497156      7556875         US  1958.0                     Pop    Vinyl
# 9073592      8084456     Russia  2004.0  Folk, World, & Country       CD
# 11306727    10222193     France  1990.0                     Pop    Vinyl
# 1141794      1173835      Spain  1988.0                    Rock    Vinyl
# 13508673    12264910    Germany  2015.0               Classical       CD
# 8995989      8012357         US  1926.0                    Jazz  Shellac
# 8836541      7865011         US  2009.0              Electronic     File
# 1108844      1143566  Australia  1993.0                     Pop       CD
# 9537485      8511641     Russia     NaN                    Rock      DVD

# %%
df_discogs_releases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17372035 entries, 0 to 17372034
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   release_id  int64
#  1   country     object
#  2   year        float64
#  3   genre       object
#  4   format      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 662.7+ MB

# %% [markdown]
# #### Backing up the dataframe for further use

# %%
project_pack.dictionary['df_discogs_releases'].backup()

# %% [markdown]
# ## Bandcamp

# %% [markdown]
# Source: https://www.kaggle.com/datasets/mathurinache/1000000-bandcamp-sales
#
# This dataset contains 1,000,000 items from Bandcamp's sales feed between 9/9/2020 and 10/2/2020, and is a slice of the whole dataset used in The Chaos Bazaar. It contains the following columns:
#
# - _id: unique identifier combining the sale's URL and UTC timestamp.
# - url: the path to the item on Bandcamp. Use this column to join this dataset to the dataset of Bandcamp items.
# - artist_name: Name of the artist.
# - album_title: Title of the album, if applicable.
# - art_url: path to the item's art image.
# - item_type: denotes the type of object. a for digital albums, p for physical items, and t for digital tracks.
# - slug_type: also denotes the type of object. a for all albums, p for merch, and t for tracks.
# - utc_date: the UTC timestamp of the sale datetime.
# - country_code: country code of the buyer.
# - country: full country code name of the buyer.
# - item_price: price of the item in the seller's currency.
# - currency: the seller's currency.
# - amount_paid: amount paid in the seller's currency.
# - amount_paid_fmt: amount paid in the seller's currency, with the currency symbol.
# - amount_paid_usd: amount paid converted to US Dollars.
# - amount_over_fmt: amount voluntarily paid over the item price in the seller's currency.
#
# Sample code, charts and reports:
# https://www.kaggle.com/code/mathurinache/bandcamp-dataset-starter

# %%
df_bandcamp_sales.sample(20)
# Out:
#                                                       _id item_type  \
# 216520  1600165208.98146&//rc88.bandcamp.com/album/rc8...         a
# 101496  1599884294.88734&//astrophysicsbrazil.bandcamp...         t
# 666928  1601092341.56153&//banjoguyollie.bandcamp.com/...         a
# 309318  1600366514.45336&//lamiavox.bandcamp.com/album...         p
# 831011  1601478907.37418&https://listen.20buckspin.com...         a
# 752400  1601294906.70841&//fhlostonparadigm.bandcamp.c...         a
# 946197  1601633809.60372&//saikelabel.bandcamp.com/mer...         p
# 691294  1601139995.29481&//clppng.bandcamp.com/album/v...         p
# 367695  1600461090.92535&//eprom.bandcamp.com/track/fl...         t
# 196233  1600109537.53417&//biggiantcircles.bandcamp.co...         a
# 628260  1601044242.92514&//devaloop.bandcamp.com/album...         p
# 221883  1600177748.13948&//jaydiggs.bandcamp.com/track...         t
# 707600  1601170703.25913&//reinventionofromance.bandca...         p
# 626953  1601042811.79642&//cultofparthenope.bandcamp.c...         p
# 746978             1601277851.66247&//chooyu.bandcamp.com         b
# 299006  1600350208.77863&//asemanual.bandcamp.com/trac...         t
# 572063  1600941467.03193&//chrisstussy.bandcamp.com/al...         a
# 843881  1601499138.03441&//darkdescent.bandcamp.com/tr...         t
# 237383  1600203159.58542&//arcadiasounds.bandcamp.com/...         t
# 870763  1601564066.15493&//reubenvaunsmith.bandcamp.co...         t
#
#             utc_date country_code         country slug_type  \
# 216520  1.600165e+09           fr          France         a
# 101496  1.599884e+09           au       Australia         t
# 666928  1.601092e+09           se          Sweden         a
# 309318  1.600367e+09           us   United States         a
# 831011  1.601479e+09           gb  United Kingdom         a
# 752400  1.601295e+09           au       Australia         a
# 946197  1.601634e+09           fr          France         p
# 691294  1.601140e+09           us   United States         a
# 367695  1.600461e+09           ca          Canada         t
# 196233  1.600110e+09           us   United States         a
# 628260  1.601044e+09           at         Austria         a
# 221883  1.600178e+09           ie         Ireland         t
# 707600  1.601171e+09           us   United States         a
# 626953  1.601043e+09           it           Italy         a
# 746978  1.601278e+09           de         Germany       NaN
# 299006  1.600350e+09           gb  United Kingdom         t
# 572063  1.600941e+09           gb  United Kingdom         a
# 843881  1.601499e+09           gb  United Kingdom         t
# 237383  1.600203e+09           gb  United Kingdom         t
# 870763  1.601564e+09           it           Italy         t
#
#                               item_description        art_id  \
# 216520         RC88's Fighting is Magic Tracks  3.093735e+09
# 101496                    Sweden (Bonus Track)  7.663462e+08
# 666928                          Amiga Classics  1.097989e+09
# 309318            Limited Edition Double Vinyl           NaN
# 831011                                 Stygian  4.077586e+09
# 752400                      Right Where We Are  3.535556e+09
# 946197             SAIKE+01 T-shirt VIPER DIVA           NaN
# 691294                      Loser Edition 2xLP           NaN
# 367695                                FleshNet  3.257936e+09
# 196233                              Max Effect  1.588384e+09
# 628260              “Limited Edition 12" Vinyl           NaN
# 221883                           W.A.P. (Funk)  5.224078e+08
# 707600       Limited Edition 180g Double Vinyl           NaN
# 626953                     "Humans" CD edition           NaN
# 746978  full digital discography (10 releases)  3.437601e+09
# 299006                            Lawdaa Mercy  1.167338e+09
# 572063              stussko - audio control ep  1.484648e+09
# 843881         At The Gates (The Fallen Remix)  2.096927e+09
# 237383                      B1. PINDER - Ousey  4.097632e+09
# 870763                       Under The Thunder  1.581987e+09
#
#                                                       url  releases  \
# 216520  //rc88.bandcamp.com/album/rc88s-fighting-is-ma...       NaN
# 101496  //astrophysicsbrazil.bandcamp.com/track/sweden...       NaN
# 666928  //banjoguyollie.bandcamp.com/album/amiga-classics       NaN
# 309318  //lamiavox.bandcamp.com/album/sigillum-diaboli...       NaN
# 831011        https://listen.20buckspin.com/album/stygian       NaN
# 752400  //fhlostonparadigm.bandcamp.com/album/right-wh...       NaN
# 946197  //saikelabel.bandcamp.com/merch/saike-01-t-shi...       NaN
# 691294  //clppng.bandcamp.com/album/visions-of-bodies-...       NaN
# 367695                //eprom.bandcamp.com/track/fleshnet       NaN
# 196233    //biggiantcircles.bandcamp.com/album/max-effect       NaN
# 628260  //devaloop.bandcamp.com/album/of-passionate-na...       NaN
# 221883           //jaydiggs.bandcamp.com/track/w-a-p-funk       NaN
# 707600  //reinventionofromance.bandcamp.com/album/the-...       NaN
# 626953       //cultofparthenope.bandcamp.com/album/humans       NaN
# 746978                              //chooyu.bandcamp.com      10.0
# 299006      //asemanual.bandcamp.com/track/lawdaa-mercy-2       NaN
# 572063  //chrisstussy.bandcamp.com/album/stussko-audio...       NaN
# 843881  //darkdescent.bandcamp.com/track/at-the-gates-...       NaN
# 237383  //arcadiasounds.bandcamp.com/track/b1-pinder-o...       NaN
# 870763  //reubenvaunsmith.bandcamp.com/track/under-the...       NaN
#
#                                               artist_name  \
# 216520                                    Stuart Ferguson
# 101496                                       Astrophysics
# 666928                                    Banjo Guy Ollie
# 309318                                          Lamia Vox
# 831011                                         Atramentus
# 752400                                  Fhloston Paradigm
# 946197                                              SAIKE
# 691294                                          clipping.
# 367695                                              EPROM
# 196233                                  Big Giant Circles
# 628260                             Samura Loré & Devaloop
# 221883                                          Jay Diggs
# 707600                                      Sarah Hennies
# 626953                                   Eight Lives Down
# 746978                                    CHO OYU records
# 299006                                         Ase Manual
# 572063                                            stussko
# 843881                                             X-Core
# 237383  Nathan Pinder, Eastfield Swing, PINDER, Cesare...
# 870763                                  Reuben Vaun Smith
#
#                                            album_title  amount_paid_usd  \
# 216520                                             NaN             2.00
# 101496                             Bittersweet Reality             1.00
# 666928                                             NaN             9.00
# 309318                      Sigillum Diaboli, re-issue            28.34
# 831011                                             NaN             7.77
# 752400                                             NaN             8.00
# 946197                                             NaN            29.29
# 691294                  Visions of Bodies Being Burned            28.00
# 367695                                             NaN             1.90
# 196233                                             NaN             1.00
# 628260                            Of Passionate Nature            21.00
# 221883                                             NaN             2.00
# 707600                      The Reinvention of Romance            27.00
# 626953                                          Humans            14.00
# 746978                                             NaN             0.40
# 299006  Ase Manual - Black Liquid Electronics (Deluxe)             1.00
# 572063                                             NaN             7.00
# 843881                                 Collapsed World             1.17
# 237383                                    ARCTERIX 003             2.57
# 870763                                     Warm Nights             1.28
#
#        amount_over_fmt item_slug
# 216520             NaN       NaN
# 101496             NaN       NaN
# 666928             NaN       NaN
# 309318             NaN       NaN
# 831011             NaN       NaN
# 752400             NaN       NaN
# 946197             NaN       NaN
# 691294             NaN       NaN
# 367695             NaN       NaN
# 196233             NaN       NaN
# 628260             NaN       NaN
# 221883             NaN       NaN
# 707600             NaN       NaN
# 626953             NaN       NaN
# 746978             NaN       NaN
# 299006             NaN       NaN
# 572063             NaN       NaN
# 843881             NaN       NaN
# 237383             NaN       NaN
# 870763             NaN       NaN

# %%
df_bandcamp_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   _id                    1000000 non-null  object
#  1   art_url                1000000 non-null  object
#  2   item_type              1000000 non-null  object
#  3   utc_date               1000000 non-null  float64
#  4   country_code           1000000 non-null  object
#  5   track_album_slug_text  2237 non-null     object
#  6   country                1000000 non-null  object
#  7   slug_type              988416 non-null   object
#  8   amount_paid_fmt        1000000 non-null  object
#  9   item_price             1000000 non-null  float64
#  10  item_description       999977 non-null   object
#  11  art_id                 764520 non-null   float64
#  12  url                    1000000 non-null  object
#  13  amount_paid            1000000 non-null  float64
#  14  releases               11584 non-null    float64
#  15  artist_name            999990 non-null   object
#  16  currency               1000000 non-null  object
#  17  album_title            356461 non-null   object
#  18  amount_paid_usd        1000000 non-null  float64
#  19  package_image_id       232708 non-null   float64
#  20  amount_over_fmt        119133 non-null   object
#  21  item_slug              21742 non-null    object
#  22  addl_count             21742 non-null    float64
# dtypes: float64(8), object(15)
# memory usage: 175.5+ MB

# %% [markdown]
# #### Dropping columns that are not important for sure in the context of this project
# - artworks
# - keep only 'amount_paid_usd' for the purchase value, as it is unified
# - currency is dropped because because there is a column country and all payments are unified to usd

# %%
columns_to_drop = ['track_album_slug_text', 'package_image_id', 'art_url', 'amount_paid_fmt', 'amount_paid', 'addl_count', 'item_price', 'currency']
df_bandcamp_sales.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# #### Backing up the dataframe for further use

# %%
project_pack.dictionary['df_bandcamp_sales'].backup()

# %% [markdown]
# ### Backup the dataset dictionary for maintenance purposes

# %%
project_pack.backup_pack()
